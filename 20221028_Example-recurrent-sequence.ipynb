# %%
an = 1
for i in range(2,100):
    an = 1/2 * (an + 2/an)
    print('a_',i,' = ',an)
# Out:
# a_ 2  =  1.5
# a_ 3  =  1.4166666666666665
# a_ 4  =  1.4142156862745097
# a_ 5  =  1.4142135623746899
# a_ 6  =  1.414213562373095
# a_ 7  =  1.414213562373095
# a_ 8  =  1.414213562373095
# a_ 9  =  1.414213562373095
# a_ 10  =  1.414213562373095
# a_ 11  =  1.414213562373095
# a_ 12  =  1.414213562373095
# a_ 13  =  1.414213562373095
# a_ 14  =  1.414213562373095
# a_ 15  =  1.414213562373095
# a_ 16  =  1.414213562373095
# a_ 17  =  1.414213562373095
# a_ 18  =  1.414213562373095
# a_ 19  =  1.414213562373095
# a_ 20  =  1.414213562373095
# a_ 21  =  1.414213562373095
# a_ 22  =  1.414213562373095
# a_ 23  =  1.414213562373095
# a_ 24  =  1.414213562373095
# a_ 25  =  1.414213562373095
# a_ 26  =  1.414213562373095
# a_ 27  =  1.414213562373095
# a_ 28  =  1.414213562373095
# a_ 29  =  1.414213562373095
# a_ 30  =  1.414213562373095
# a_ 31  =  1.414213562373095
# a_ 32  =  1.414213562373095
# a_ 33  =  1.414213562373095
# a_ 34  =  1.414213562373095
# ...

# %%
import math
math.sqrt(2)
# Out:
# 1.4142135623730951
